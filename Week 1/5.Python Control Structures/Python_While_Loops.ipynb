# %% [markdown]
# # Day 5 Continued: While Loops in Python 🌟🎉🚀
#
# Hello again, Pythonista! 🎉👨‍💻👩‍💻 We are still on Day 5 of the 30 days of Python code challenge. Now, let's dive into While Loops in Python.
#
# ## While Loops in Python 🔄
#
# The `while` loop in Python is used to iterate over a block of code as long as the test expression (condition) is true.
#
# 1. **The While Loop**: Here's a simple example:
#
# \# Simple while loop
# counter = 0
# while counter < 5:
#     print(counter)
#     counter += 1
#
# 2. **The break Statement**: The `break` statement in Python terminates the current loop and resumes execution at the next statement.
#
# Example:
#
# \# While loop with break
# counter = 0
# while counter < 5:
#     print(counter)
#     if counter == 3:
#         break
#     counter += 1
#
# 3. **The continue Statement**: The `continue` statement in Python returns the control to the beginning of the loop. The `continue` statement rejects all the remaining statements in the current iteration of the loop and moves the control back to the top of the loop.
#
# Example:
#
# \# While loop with continue
# counter = 0
# while counter < 5:
#     counter += 1
#     if counter == 3:
#         continue
#     print(counter)
#
# 4. **The else Statement with While Loop**: Python supports having an `else` statement associated with a loop statement. The `else` block just after `for/while` is executed only when the loop is NOT terminated by a `break` statement.
#
# Example:
#
# \# While loop with else
# counter = 0
# while counter < 5:
#     print(counter)
#     counter += 1
# else:
#     print("End of while loop")
#
# 5. **Nested While Loops**: Python programming language allows the usage of one loop inside another loop. A loop inside another loop is called a nested loop.
#
# Example:
#
# \# Nested while loop
# i = 0
# while i < 3:
#     j = 0
#     while j < 3:
#         print(i, j)
#         j += 1
#     i += 1
#
# ## Exercise 🏋️‍♀️🤓🎯🏁
#
# 1. Write a Python program that prints all the numbers from 0 to 10 except 3 and 6 using a while loop and continue statement.
#
# 2. Write a Python program to count the number of even and odd numbers from a series of numbers using a while loop.
#
# 3. Write a Python program that uses a while loop to print the first 10 Fibonacci numbers.
#
# 4. Write a Python program using a while loop that asks the user for a number, and prints a countdown from that number to zero.
#
# Happy Coding! 🚀👩‍💻👨‍💻💻🌟
